# %%
import numpy as np
heights = [120,130,134,123,151,104,142] # used a sample set of heights from task 1
np_height_in = np.array(heights)
print("Height in inches: ", np_height_in) # to make it to relevant to given solution at the end
np_height_m = np_height_in * 0.0254
print("Height in meters: ", np_height_m)
# Out:
# Height in inches:  [120 130 134 123 151 104 142]
# Height in meters:  [3.048  3.302  3.4036 3.1242 3.8354 2.6416 3.6068]
