# %%
import numpy as np
heights = [120,130,134,123,151,104,142]
np_height_in = np.array(heights)
print("Height in inches: ", np_height_in)
np_height_m = np_height_in * 0.0254
print("Height in meters: ", np_height_m)
#task 2 above
weights = [80,91,85,88,77,99,101]
print("Weight in pounds: ", weights)
np_weight_kg = np.array(weights) * 0.453592
print("Weight in kilograms: ", np_weight_kg)
bmi = np_weight_kg / np_height_m ** 2
print("BMI: ", bmi)
# Out:
# Height in inches:  [120 130 134 123 151 104 142]
# Height in meters:  [3.048  3.302  3.4036 3.1242 3.8354 2.6416 3.6068]
# Weight in pounds:  [80, 91, 85, 88, 77, 99, 101]
# Weight in kilograms:  [36.28736  41.276872 38.55532  39.916096 34.926584 44.905608 45.812792]
# BMI:  [3.90593892 3.78575619 3.32818364 4.08950179 2.37429558 6.4352655
#  3.52162119]
