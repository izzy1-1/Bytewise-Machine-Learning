# %%
import numpy as np
baseball = [120,130,134,123,151,104,142] # used a sample set of heights
np_array = np.array(baseball) # converted the list to an array using np.array in-built function
print(type(np_array)) # printed the type
print(np_array) # printed the actual array contents
# Out:
# <class 'numpy.ndarray'>
# [120 130 134 123 151 104 142]
